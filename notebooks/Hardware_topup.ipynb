# %% [markdown]
# # Hardware-Requirement Enrichment Layer
# ----------------
# **MSc Data Science Dissertation**
# **Author:** Vikrant Deshmukh
# **University:** University of Bristol
# **Project:** Video Game Recommendation System
# **MSc Data Science Dissertation**

# %% [markdown]
# ## Objective
#
# This notebook extends the final Hybrid recommendation system with a
# post-recommendation hardware requirement enrichment layer.
#
# The system follows the pipeline:
#
# 1. Generate relevant game recommendations using the final Hybrid Recommender.
# 2. Retrieve minimum and recommended PC hardware requirements for the recommended games.
# 3. Parse and standardise the retrieved hardware requirements.
# 4. Cache retrieved Steam requirements to avoid repeated API requests.
# 5. Convert RAM and storage values into numerical GB values where possible.
# 6. Attach the structured hardware information to the original Hybrid recommendations while preserving the Hybrid ranking.
#
# The hardware-aware layer does not replace the hybrid recommender. Instead, it acts as a post-recommendation compatibility layer that considers whether relevant games are practical for the user's hardware.

# %% [markdown]
# ## Importing liabraries and paths

# %%
# importing core liabraries
from pathlib import Path
import pandas as pd
import numpy as np
import os
import re
import time
import requests

from bs4 import BeautifulSoup

# %%
IN_COLAB = "COLAB_RELEASE_TAG" in os.environ

if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Configure the project and dataset paths.

if IN_COLAB:
    PROJECT_ROOT = Path("/content/drive/MyDrive/MSC_DISSERTATION")
else:
    PROJECT_ROOT = Path.cwd()

DATA_DIR = PROJECT_ROOT / "Data"
OUTPUT_DIR = PROJECT_ROOT / "Output/live_outputs"

data_path = DATA_DIR / "games_clean_v1.csv"

if not data_path.exists():
    raise FileNotFoundError(f"Dataset not found at: {data_path}")

games = pd.read_csv(data_path)

print("Dataset loaded successfully.")
print("Dataset shape:", games.shape)
# Out:
# Dataset loaded successfully.
# Dataset shape: (89618, 50)

# %%
# Main dissertation folders

PROJECT_DIR = Path(
    "/content/drive/MyDrive/MSC_DISSERTATION"
)

DATA_DIR = PROJECT_DIR / "Data"

NOTEBOOK_DIR = (
    PROJECT_DIR
    / "Notebooks"
    / "Final Notebooks"
)

OUTPUT_DIR = (
    PROJECT_DIR
    / "Output"
    / "evaluation_outputs"
)

# Existing final hybrid notebook

HYBRID_NOTEBOOK_PATH = (
    NOTEBOOK_DIR
    / "Hybrid_Recommender.ipynb"
)

# Persistent Steam hardware-requirements cache

CACHE_PATH = (
    DATA_DIR
    / "hardware_requirements_cache.csv"
)

# Future final hardware-aware output

HARDWARE_OUTPUT_PATH = (
    OUTPUT_DIR
    / "hardware_aware_recommendations.csv"
)

print("Project directory:", PROJECT_DIR)
print("Hybrid notebook:", HYBRID_NOTEBOOK_PATH)
print("Hardware cache:", CACHE_PATH)
# Out:
# Project directory: /content/drive/MyDrive/MSC_DISSERTATION
# Hybrid notebook: /content/drive/MyDrive/MSC_DISSERTATION/Notebooks/Final Notebooks/Hybrid_Recommender.ipynb
# Hardware cache: /content/drive/MyDrive/MSC_DISSERTATION/Data/hardware_requirements_cache.csv

# %% [markdown]
# ## 1. Load the Final Hybrid Recommender
#
# The hardware-aware system uses the existing final hybrid recommender as its recommendation source.
#
# The hybrid model remains unchanged. Its live `hybrid_recommend()` interface is loaded here so that the hardware layer can operate on recommendations for any eligible catalogue game.

# %%
# %run "/content/drive/MyDrive/MSC_DISSERTATION/Notebooks/Final Notebooks/Hybrid_Recommender.ipynb"

print("Hybrid recommender loaded.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset loaded successfully.
# Dataset shape: (89618, 50)
# All candidate files are available.
# Metadata shape: (500, 16)
# Graph shape: (500, 16)
# Semantic shape: (500, 13)
# All candidate files passed validation.
# Shared query games: 10
# Hybrid configuration is valid.
# Metadata fusion shape: (500, 6)
# Graph fusion shape: (500, 6)
# Semantic fusion shape: (500, 6)
# Counter-Strike 2 | recommendations: 10 | runtime: 0.02875 seconds
# Grand Theft Auto V Legacy | recommendations: 10 | runtime: 0.027058 seconds
# Sid Meier’s Civilization® VI | recommendations: 10 | runtime: 0.026507 seconds
# The Witcher 3: Wild Hunt | recommendations: 10 | runtime: 0.026632 seconds
# Hollow Knight | recommendations: 10 | runtime: 0.031585 seconds
# Stardew Valley | recommendations: 10 | runtime: 0.027329 seconds
# Factorio | recommendations: 10 | runtime: 0.027169 seconds
# Deep Rock Galactic | recommendations: 10 | runtime: 0.034832 seconds
# Phasmophobia | recommendations: 10 | runtime: 0.035994 seconds
# Hades | recommendations: 10 | runtime: 0.027495 seconds
#
# Hybrid result shape: (100, 13)
# Runtime result shape: (10, 4)
# Number of query games: 10
#
# Recommendations per query:
# query_appid
# 730        10
# 271590     10
# 289070     10
# 292030     10
# 367520     10
# 413150     10
# 427520     10
# 548430     10
# 739630     10
# 1145360    10
# dtype: int64
#
# Duplicate pairs: 0
# Self-recommendations: 0
# Queries with rank issues: 0
#
# Final hybrid output passed validation.
#                    query_game  hybrid_rank  \
# 0            Counter-Strike 2            1
# 1            Counter-Strike 2            2
# 2            Counter-Strike 2            3
# 3            Counter-Strike 2            4
# 4            Counter-Strike 2            5
# 5            Counter-Strike 2            6
# 6            Counter-Strike 2            7
# 7            Counter-Strike 2            8
# 8            Counter-Strike 2            9
# 9            Counter-Strike 2           10
# 10  Grand Theft Auto V Legacy            1
# 11  Grand Theft Auto V Legacy            2
# 12  Grand Theft Auto V Legacy            3
# 13  Grand Theft Auto V Legacy            4
# 14  Grand Theft Auto V Legacy            5
# 15  Grand Theft Auto V Legacy            6
# 16  Grand Theft Auto V Legacy            7
# 17  Grand Theft Auto V Legacy            8
# 18  Grand Theft Auto V Legacy            9
# 19  Grand Theft Auto V Legacy           10
#
#                                         recommended_game  metadata_rank  \
# 0                                 Counter-Strike: Source            2.0
# 1                                              Splitgate            1.0
# 2                        Tom Clancy's Rainbow Six® Siege            7.0
# 3                                        Team Fortress 2            3.0
# 4                                             Insurgency            6.0
# 5                                              Ironsight           11.0
# 6                                                VAIL VR            4.0
# 7                                                Warfork           17.0
# 8                                            Black Squad            5.0
# 9                                             Lightphobe           41.0
# 10                           Grand Theft Auto V Enhanced            1.0
# 11                                 Red Dead Redemption 2            3.0
# 12  Grand Theft Auto: Vice City – The Definitive Edition           24.0
# 13             Grand Theft Auto IV: The Complete Edition            2.0
# 14                                         Just Cause™ 3            5.0
# 15                                 Saints Row: The Third            8.0
# 16                                         Watch_Dogs® 2            4.0
# 17                         Mafia III: Definitive Edition            9.0
# 18                           Saints Row: Gat out of Hell           13.0
# 19                             Mafia: Definitive Edition           16.0
#
#     graph_rank  semantic_rank  model_agreement  hybrid_rrf_score
# 0          1.0            1.0                3          0.016288
# 1          5.0            NaN                2          0.012711
# 2          2.0            NaN                2          0.012422
# 3          6.0            NaN                2          0.012410
# 4          3.0            NaN                2          0.012410
# 5         31.0           34.0                3          0.012157
# 6         13.0            NaN                2          0.011729
# 7          9.0            NaN                2          0.010992
# 8         28.0            NaN                2          0.010699
# 9          4.0            NaN                2          0.010210
# 10         1.0            1.0                3          0.016393
# 11         7.0           46.0                3          0.014206
# 12        16.0            3.0                3          0.013200
# 13         2.0            NaN                2          0.012903
# 14         3.0            NaN                2          0.012503
# 15         4.0            NaN                2          0.012132
# 16        10.0            NaN                2          0.011964
# 17         6.0            NaN                2          0.011858
# 18         8.0            NaN                2          0.011362
# 19         9.0            NaN                2          0.011060
# Model agreement distribution:
# model_agreement
# 2    73
# 3    27
# Name: count, dtype: int64
# Hybrid recommendations saved to: /content/drive/MyDrive/MSC_DISSERTATION/Output/evaluation_outputs/hybrid_evaluation_recommendations.csv
# Hybrid runtime saved to: /content/drive/MyDrive/MSC_DISSERTATION/Output/evaluation_outputs/hybrid_evaluation_runtime.csv
# Current | {'metadata': 0.4, 'graph': 0.4, 'semantic': 0.2} | Total: 1.0
# Equal | {'metadata': 0.3333333333333333, 'graph': 0.3333333333333333, 'semantic': 0.3333333333333333} | Total: 1.0
# Metadata-heavy | {'metadata': 0.5, 'graph': 0.3, 'semantic': 0.2} | Total: 1.0
# Graph-heavy | {'metadata': 0.3, 'graph': 0.5, 'semantic': 0.2} | Total: 1.0
#
# Running configuration: Current
#
# Running configuration: Equal
#
# Running configuration: Metadata-heavy
#
# Running configuration: Graph-heavy
#
# Sensitivity result shape: (400, 17)
#
# Recommendations per configuration:
# weight_configuration
# Current           100
# Equal             100
# Metadata-heavy    100
# Graph-heavy       100
# Name: count, dtype: int64
#      hybrid_rank  query_appid                    query_game    appid  \
# 100            1          730              Counter-Strike 2      240
# 45             6       367520                 Hollow Knight  1154680
# 6              7          730              Counter-Strike 2   801550
# 315            6       271590     Grand Theft Auto V Legacy    55230
# 228            9       289070  Sid Meier’s Civilization® VI   489630
# 227            8       289070  Sid Meier’s Civilization® VI   226860
# 356            7       413150                Stardew Valley  2627600
# 178            9       548430            Deep Rock Galactic   235540
# 259           10       413150                Stardew Valley  1465550
# 235            6       292030      The Witcher 3: Wild Hunt   253980
# 263            4       427520                      Factorio  1457320
# 174            5       548430            Deep Rock Galactic  2233700
# 44             5       367520                 Hollow Knight   597860
# 141            2       367520                 Hollow Knight  1891740
# 1              2          730              Counter-Strike 2   677620
# 333            4       292030      The Witcher 3: Wild Hunt    40300
# 139           10       292030      The Witcher 3: Wild Hunt    65540
# 237            8       292030      The Witcher 3: Wild Hunt    39500
# 241            2       367520                 Hollow Knight   814680
# 94             5      1145360                         Hades  1040420
#
#                               recommended_game  metadata_rank  graph_rank  \
# 100                     Counter-Strike: Source            2.0         1.0
# 45                                   The Guise            4.0        10.0
# 6                                      VAIL VR            4.0        13.0
# 315                      Saints Row: The Third            8.0         4.0
# 228  Warhammer 40,000: Gladius - Relics of War            4.0        18.0
# 227                 Galactic Civilizations III           19.0        32.0
# 356                               Project Real            5.0         5.0
# 178          Warhammer: End Times - Vermintide           17.0        31.0
# 259                         One Lonely Outpost            4.0        10.0
# 235                                    Enclave            7.0         4.0
# 263                                 Techtonica            2.0        10.0
# 174               Last Night in Zombie Village           22.0        11.0
# 44                               Nightmare Boy            5.0         7.0
# 141          Lost Wish: In the desperate world            1.0         2.0
# 1                                    Splitgate            1.0         5.0
# 333                                      Risen            1.0         7.0
# 139                                   Gothic 1           12.0         9.0
# 237                                  Gothic® 3            9.0         5.0
# 241                      Unbound: Worlds Apart            2.0         1.0
# 94                                 Dreamscaper            4.0         8.0
#
#      semantic_rank  model_agreement  metadata_rrf  graph_rrf  semantic_rrf  \
# 100            1.0                3      0.005376   0.005464      0.005464
# 45             NaN                2      0.006250   0.005714      0.000000
# 6              NaN                2      0.006250   0.005479      0.000000
# 315            NaN                2      0.004412   0.007812      0.000000
# 228            NaN                2      0.007812   0.003846      0.000000
# 227           29.0                3      0.006329   0.003261      0.002247
# 356            NaN                2      0.004615   0.007692      0.000000
# 178            NaN                2      0.004329   0.003663      0.000000
# 259            NaN                2      0.007812   0.004286      0.000000
# 235            NaN                2      0.007463   0.004687      0.000000
# 263           32.0                3      0.008065   0.004286      0.002174
# 174            NaN                2      0.004065   0.004695      0.000000
# 44             NaN                2      0.006154   0.005970      0.000000
# 141            NaN                2      0.005464   0.005376      0.000000
# 1              NaN                2      0.006557   0.006154      0.000000
# 333            NaN                2      0.004918   0.007463      0.000000
# 139            NaN                2      0.004630   0.004831      0.000000
# 237            NaN                2      0.007246   0.004615      0.000000
# 241            NaN                2      0.008065   0.004918      0.000000
# 94             NaN                2      0.006250   0.005882      0.000000
#
#      hybrid_rrf_score weight_configuration  metadata_weight  graph_weight  \
# 100          0.016305                Equal         0.333333      0.333333
# 45           0.011964              Current         0.400000      0.400000
# 6            0.011729              Current         0.400000      0.400000
# 315          0.012224          Graph-heavy         0.300000      0.500000
# 228          0.011659       Metadata-heavy         0.500000      0.300000
# 227          0.011837       Metadata-heavy         0.500000      0.300000
# 356          0.012308          Graph-heavy         0.300000      0.500000
# 178          0.007992                Equal         0.333333      0.333333
# 259          0.012098       Metadata-heavy         0.500000      0.300000
# 235          0.012150       Metadata-heavy         0.500000      0.300000
# 263          0.014524       Metadata-heavy         0.500000      0.300000
# 174          0.008760                Equal         0.333333      0.333333
# 44           0.012124              Current         0.400000      0.400000
# 141          0.010841                Equal         0.333333      0.333333
# 1            0.012711              Current         0.400000      0.400000
# 333          0.012381          Graph-heavy         0.300000      0.500000
# 139          0.009461                Equal         0.333333      0.333333
# 237          0.011862       Metadata-heavy         0.500000      0.300000
# 241          0.012983       Metadata-heavy         0.500000      0.300000
# 94           0.012132              Current         0.400000      0.400000
#
#      semantic_weight
# 100         0.333333
# 45          0.200000
# 6           0.200000
# 315         0.200000
# 228         0.200000
# 227         0.200000
# 356         0.200000
# 178         0.333333
# 259         0.200000
# 235         0.200000
# 263         0.200000
# 174         0.333333
# 44          0.200000
# 141         0.333333
# 1           0.200000
# 333         0.200000
# 139         0.333333
# 237         0.200000
# 241         0.200000
# 94          0.200000
# Configurations: 4
#
# Queries per configuration:
# weight_configuration
# Current           10
# Equal             10
# Graph-heavy       10
# Metadata-heavy    10
# Name: query_appid, dtype: int64
#
# Unique recommendation counts:
# [np.int64(10)]
#
# Duplicate pairs: 0
# Self-recommendations: 0
#
# RRF sensitivity output passed validation.
# RRF sensitivity results saved to:
# /content/drive/MyDrive/MSC_DISSERTATION/Output/evaluation_outputs/rrf_weight_sensitivity_results.csv
# Live source notebooks are available.
# Live source recommenders loaded: semantic, graph, metadata
#     hybrid_rank    appid                                   recommended_game  \
# 0             1  2653880                                              Amber
# 1             2  2513170                                     Origami Lovers
# 2             3  2735110                                An Eternity Gone By
# 3             4   916140                                 The Tale of Bistun
# 4             5  2021040                                   Shards of Nogard
# 5             6   645320                                              SCARF
# 6             7  1015890                     TASOMACHI: Behind the Twilight
# 7             8  2169570  The Lost Legends of Redwall™: The Scout Anthology
# 8             9   843180            Clan O'Conall and the Crown of the Stag
# 9            10  1977170                                             Jusant
# 10           11  3416630                                       DEBIE ZONE 2
# 11           12   990630                                  The Last Campfire
# 12           13   908480                                Legends of Ethernal
# 13           14  2283470                         Runa & the Chaikurú Legacy
# 14           15  1044410                           Little Gods of the Abyss
#
#     hybrid_rrf_score  model_agreement
# 0           0.013115                2
# 1           0.012512                2
# 2           0.012503                2
# 3           0.012220                2
# 4           0.012007                2
# 5           0.011120                2
# 6           0.011120                2
# 7           0.011069                2
# 8           0.010797                2
# 9           0.010658                2
# 10          0.010605                2
# 11          0.010343                2
# 12          0.009923                2
# 13          0.009722                2
# 14          0.009518                2
#     hybrid_rank    appid                        recommended_game  \
# 0             1  1240440                           Halo Infinite
# 1             2    49540     Aliens: Colonial Marines Collection
# 2             3   415590                               Earthfall
# 3             4   204340                           Serious Sam 2
# 4             5   753640                             Outer Wilds
# 5             6  1058020  STAR WARS™ Battlefront (Classic, 2004)
# 6             7    13520                                Far Cry®
# 7             8    41000     Serious Sam HD: The First Encounter
# 8             9  1927030                                  UFOBIA
# 9            10  3325840                            Hollow Space
# 10           11   397540                           Borderlands 3
# 11           12   362890                              Black Mesa
# 12           13   273620                             Freespace 2
# 13           14   202970             Call of Duty®: Black Ops II
# 14           15   459220           Halo Wars: Definitive Edition
#
#     hybrid_rrf_score  model_agreement
# 0           0.014078                3
# 1           0.012907                2
# 2           0.012334                2
# 3           0.011511                2
# 4           0.011263                2
# 5           0.011111                2
# 6           0.011039                2
# 7           0.010889                2
# 8           0.010653                2
# 9           0.010142                2
# 10          0.010096                2
# 11          0.009944                2
# 12          0.009543                2
# 13          0.009402                2
# 14          0.009328                2
# Hybrid recommender loaded.

# %%
## testing phase

hybrid_test = hybrid_recommend(
    "red dead redemption 2",
    top_n= 5
)

display(hybrid_test)
# Out:
#    hybrid_rank  query_appid             query_game    appid  \
# 0            1      1174180  Red Dead Redemption 2  1404210
# 1            2      1174180  Red Dead Redemption 2   271590
# 2            3      1174180  Red Dead Redemption 2   287700
# 3            4      1174180  Red Dead Redemption 2   360430
# 4            5      1174180  Red Dead Redemption 2   447040
#
#                        recommended_game  metadata_rank  graph_rank  \
# 0                       Red Dead Online            1.0         1.0
# 1             Grand Theft Auto V Legacy            2.0         2.0
# 2  METAL GEAR SOLID V: THE PHANTOM PAIN            4.0         3.0
# 3         Mafia III: Definitive Edition            5.0         4.0
# 4                         Watch_Dogs® 2            6.0        12.0
#
#    semantic_rank  model_agreement  metadata_rrf  graph_rrf  semantic_rrf  \
# 0            1.0                3      0.006557   0.006557      0.003279
# 1            NaN                2      0.006452   0.006452      0.000000
# 2            NaN                2      0.006250   0.006349      0.000000
# 3            NaN                2      0.006154   0.006250      0.000000
# 4            NaN                2      0.006061   0.005556      0.000000
#
#    hybrid_rrf_score
# 0          0.016393
# 1          0.012903
# 2          0.012599
# 3          0.012404
# 4          0.011616

# %% [markdown]
# ## 2. Steam Hardware Requirement Retrieval
#
# The hardware-aware layer retrieves PC system requirements using the Steam Store API and Steam AppIDs produced by the hybrid recommender.
#
# Only games returned by the hybrid recommender are queried. Retrieved requirements are stored in a persistent local cache to avoid unnecessary repeated API requests.

# %%
def clean_requirement_html(html_text):
    if not html_text:
        return None

    soup = BeautifulSoup(html_text, "html.parser")
    return soup.get_text(separator="\n", strip=True)

# %%
def fetch_requirements(appid):

  url = "https://store.steampowered.com/api/appdetails"

  paremeters = {"appids": int(appid),
                "l": "en"}

  response = requests.get(url, params=paremeters, timeout = 20)

  data = response.json()
  game = data[str(int(appid))]

  if not game["success"]:
    return None

  game_data = game["data"]

  pc_requirements = game_data.get("pc_requirements", {})

  return {
        "appid": int(appid),
        "game_name": game_data.get("name"),
        "minimum_requirements": clean_requirement_html(
            pc_requirements.get("minimum")
        ),
        "recommended_requirements": clean_requirement_html(
            pc_requirements.get("recommended")
        )
    }

# %%
fetch_requirements(1245620)
# Out:
# {'appid': 1245620,
#  'game_name': 'ELDEN RING',
#  'minimum_requirements': 'Minimum:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10\nProcessor:\nINTEL CORE I5-8400 or AMD RYZEN 3 3300X\nMemory:\n12 GB RAM\nGraphics:\nNVIDIA GEFORCE GTX 1060 3 GB or AMD RADEON RX 580 4 GB\nDirectX:\nVersion 12\nStorage:\n60 GB available space\nSound Card:\nWindows Compatible Audio Device\nAdditional Notes:',
#  'recommended_requirements': 'Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10/11\nProcessor:\nINTEL CORE I7-8700K or AMD RYZEN 5 3600X\nMemory:\n16 GB RAM\nGraphics:\nNVIDIA GEFORCE GTX 1070 8 GB or AMD RADEON RX VEGA 56 8 GB\nDirectX:\nVersion 12\nStorage:\n60 GB available space\nSound Card:\nWindows Compatible Audio Device\nAdditional Notes:'}

# %% [markdown]
# ## 3. Hardware Requirements Cache
#
# Previously retrieved Steam hardware requirements are stored in a local cache.
#
# This avoids repeated API requests for games whose requirements have already been fetched. If the cache file does not exist, an empty cache is created automatically.

# %%
def load_hardware_cache():

  if os.path.exists(CACHE_PATH):
        cache = pd.read_csv(CACHE_PATH)

  else:
        cache = pd.DataFrame(
            columns=[
                "appid",
                "game_name",
                "minimum_requirements",
                "recommended_requirements"
            ]
        )

  return cache

# %%
def is_game_cached(appid, cache):

    return int(appid) in cache["appid"].astype(int).values

# %%
hardware_cache = load_hardware_cache()

is_game_cached(
    1245620,
    hardware_cache
)
# Out:
# True

# %% [markdown]
# ### Add Missing Game to Cache
#
# If a game's AppID is not already cached, its hardware requirements are fetched from Steam and added to the local cache.

# %%
def add_game_to_cache(appid):

  cache = load_hardware_cache()

  if is_game_cached(appid, cache):
    print("Game details have already been cached")

    return cache

  new_game = fetch_requirements(appid)
  new_row = pd.DataFrame([new_game])

  cache = pd.concat(
        [cache, new_row],
        ignore_index=True
    )

  cache.to_csv(
        CACHE_PATH,
        index=False
    )

  print("Game added to cache.")

  return cache

# %%
hardware_cache = add_game_to_cache(1245620)
# Out:
# Game details have already been cached

# %%
def update_hardware_cache(appids):

    cache = load_hardware_cache()

    for appid in appids:

        if not is_game_cached(appid, cache):

            new_game = fetch_requirements(appid)

            new_row = pd.DataFrame([new_game])

            cache = pd.concat(
                [cache, new_row],
                ignore_index=True
            )

            time.sleep(0.4)

    cache.to_csv(
        CACHE_PATH,
        index=False
    )

    return cache

# %%
test_appids = hybrid_test["appid"].tolist()

hardware_cache = update_hardware_cache(
    test_appids
)

print("Cached games:", len(hardware_cache))
# Out:
# Cached games: 80

# %%
hardware_results = hybrid_test.merge(
    hardware_cache,
    on="appid",
    how="left"
)

# %%
hardware_results[
    [
        "hybrid_rank",
        "recommended_game",
        "minimum_requirements",
        "recommended_requirements"
    ]
]
# Out:
#    hybrid_rank                      recommended_game  \
# 0            1                       Red Dead Online
# 1            2             Grand Theft Auto V Legacy
# 2            3  METAL GEAR SOLID V: THE PHANTOM PAIN
# 3            4         Mafia III: Definitive Edition
# 4            5                         Watch_Dogs® 2
#
#                                                                                                       minimum_requirements  \
# 0  Minimum:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 - 64-bit\nProcessor:\nIntel® Core™ i5-25...
# 1  Minimum:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 64 Bit\nProcessor:\nIntel Core 2 Quad CP...
# 2  Minimum:\nOS:\nWindows 7x64, Windows 8x64, Windows 10x64 (64-bit OS Required)\nProcessor:\nIntel Core i5-4460 (3.40 ...
# 3  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64-bit\nProcessor:\nIntel I5-2500K, AMD...
# 4  Minimum:\nOS *:\nOriginally released for Windows 7, the game can be played on Windows 10 and Windows 11 OS\nProcesso...
#
#                                                                                                   recommended_requirements
# 0  Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 - April 2018 Update (v1803)\nProcess...
# 1  Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 64 Bit\nProcessor:\nIntel Core i5 34...
# 2  Recommended:\nOS:\nWindows 7x64, Windows 8x64, Windows 10x64 (64-bit OS Required)\nProcessor:\nIntel Core i7-4790 (3...
# 3  Recommended:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64-bit\nProcessor:\nIntel I7-3770, ...
# 4  Recommended:\nOS *:\nOriginally released for Windows 7, the game can be played on Windows 10 and Windows 11 OS\nProc...

# %% [markdown]
# ## 4. Parse Hardware Requirements
#
# Steam provides hardware requirements as semi-structured text.
# The following functions extract individual hardware fields such as operating system, processor, memory, graphics card and storage.

# %%
def extract_requirement_field(text, field_name):

    if not isinstance(text, str) or not text.strip():
        return None

    pattern = rf"{re.escape(field_name)}:\s*(.+)"

    match = re.search(
        pattern,
        text,
        flags=re.IGNORECASE
    )

    if match:
        return match.group(1).strip()

    return None

# %%
hardware_results
# Out:
#    hybrid_rank  query_appid             query_game    appid  \
# 0            1      1174180  Red Dead Redemption 2  1404210
# 1            2      1174180  Red Dead Redemption 2   271590
# 2            3      1174180  Red Dead Redemption 2   287700
# 3            4      1174180  Red Dead Redemption 2   360430
# 4            5      1174180  Red Dead Redemption 2   447040
#
#                        recommended_game  metadata_rank  graph_rank  \
# 0                       Red Dead Online            1.0         1.0
# 1             Grand Theft Auto V Legacy            2.0         2.0
# 2  METAL GEAR SOLID V: THE PHANTOM PAIN            4.0         3.0
# 3         Mafia III: Definitive Edition            5.0         4.0
# 4                         Watch_Dogs® 2            6.0        12.0
#
#    semantic_rank  model_agreement  metadata_rrf  graph_rrf  semantic_rrf  \
# 0            1.0                3      0.006557   0.006557      0.003279
# 1            NaN                2      0.006452   0.006452      0.000000
# 2            NaN                2      0.006250   0.006349      0.000000
# 3            NaN                2      0.006154   0.006250      0.000000
# 4            NaN                2      0.006061   0.005556      0.000000
#
#    hybrid_rrf_score                             game_name  \
# 0          0.016393                       Red Dead Online
# 1          0.012903             Grand Theft Auto V Legacy
# 2          0.012599  METAL GEAR SOLID V: THE PHANTOM PAIN
# 3          0.012404         Mafia III: Definitive Edition
# 4          0.011616                         Watch_Dogs® 2
#
#                                                                                                       minimum_requirements  \
# 0  Minimum:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 - 64-bit\nProcessor:\nIntel® Core™ i5-25...
# 1  Minimum:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 64 Bit\nProcessor:\nIntel Core 2 Quad CP...
# 2  Minimum:\nOS:\nWindows 7x64, Windows 8x64, Windows 10x64 (64-bit OS Required)\nProcessor:\nIntel Core i5-4460 (3.40 ...
# 3  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64-bit\nProcessor:\nIntel I5-2500K, AMD...
# 4  Minimum:\nOS *:\nOriginally released for Windows 7, the game can be played on Windows 10 and Windows 11 OS\nProcesso...
#
#                                                                                                   recommended_requirements
# 0  Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 - April 2018 Update (v1803)\nProcess...
# 1  Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10 64 Bit\nProcessor:\nIntel Core i5 34...
# 2  Recommended:\nOS:\nWindows 7x64, Windows 8x64, Windows 10x64 (64-bit OS Required)\nProcessor:\nIntel Core i7-4790 (3...
# 3  Recommended:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64-bit\nProcessor:\nIntel I7-3770, ...
# 4  Recommended:\nOS *:\nOriginally released for Windows 7, the game can be played on Windows 10 and Windows 11 OS\nProc...

# %% [markdown]
# ## 5. Dynamic Hardware Requirement Retrieval
#
# This function connects the hybrid recommender with the hardware-requirement pipeline.
#
# For any valid input game, it generates hybrid recommendations, checks the hardware cache, fetches missing Steam requirements, and returns the recommendations together with their hardware information.

# %%
def get_hardware_requirements(input_game, top_n):

  ## get hybrid recommendations

  hybrid_results = hybrid_recommend(
      input_game,
      top_n=top_n
  )

  ## Extract AppIDs
  appids = hybrid_results["appid"].tolist()

  ## Update hardware cache
  hardware_cache = update_hardware_cache(appids)

  # 4. Merge hybrid results with requirements
  results = hybrid_results.merge(
        hardware_cache,
        on="appid",
        how="left"
    )

  return results

# %%
## sample check

hardware_test = get_hardware_requirements(
    'Need for Speed™ Most Wanted',
    top_n=10
)

# %%
hardware_test[
    [
        "hybrid_rank",
        "recommended_game",
        "minimum_requirements",
        "recommended_requirements"
    ]
]
# Out:
#    hybrid_rank              recommended_game  \
# 0            1   Need For Speed: Hot Pursuit
# 1            2  Burnout™ Paradise Remastered
# 2            3               Need for Speed™
# 3            4        Need for Speed™ Rivals
# 4            5  Gas Guzzlers: Combat Carnage
# 5            6     FlatOut 4: Total Insanity
# 6            7           GRIP: Combat Racing
# 7            8                   Diesel Guns
# 8            9          Need for Speed™ Heat
# 9           10        Outrunner: Neon Nights
#
#                                                                                                       minimum_requirements  \
# 0  OS *:\nWindows XP SP3, Windows XP 64-bit SP2, Windows Vista SP2 (32- or 64-bit), or Windows 7 (32- or 64-bit). (Not ...
# 1  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7, 8.1, 10 64-bit\nProcessor:\nIntel i3 2...
# 2  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\n64-bit Windows 7 or later\nProcessor:\nIntel Core...
# 3  Minimum:\nOS *:\nWindows 7 (Service Pack 2) 32-Bit\nProcessor:\nIntel 2.4 GHz Core 2 Duo or AMD 2.8 GHz Athlon X2\nM...
# 4  Minimum:\nOS *:\nVista(TM)/Windows 7/Windows 8/Windows 10\nProcessor:\nDual-core 2.0 GHz\nMemory:\n3 MB RAM\nGraphic...
# 5  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\nWindows ® 7 64bit\nProcessor:\nIntel® Core i3 / A...
# 6  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64bit\nProcessor:\nIntel Core i3-3220 o...
# 7  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64-bit 7 or Newer\nProcessor:\nQuad-cor...
# 8  Minimum:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10\nProcessor:\nFX-6350 or Equivalent; Core...
# 9  Minimum:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 or higher\nProcessor:\nIntel Core i5-25...
#
#                                                                                                   recommended_requirements
# 0                                                                                                                      NaN
# 1  Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10\nProcessor:\nIntel i5 3570K or AMD R...
# 2  Recommended:\nRequires a 64-bit processor and operating system\nOS *:\n64-bit Windows 7 or later\nProcessor:\nIntel ...
# 3  Recommended:\nOS *:\nWindows 7 (Service Pack 2)\nProcessor:\nIntel Quad-Core CPU or AMD Six Core CPU\nMemory:\n8 GB ...
# 4  Recommended:\nOS *:\nVista(TM)/Windows 7/Windows 8/Windows 10\nProcessor:\nQuad-core Q6600 2.4 GHz or Equivalent\nMe...
# 5  Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows® 10 64bit\nProcessor:\nIntel® Core i5 /...
# 6  Recommended:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64bit or Newer\nProcessor:\nIntel C...
# 7  Recommended:\nRequires a 64-bit processor and operating system\nOS *:\nWindows 7 64-bit or Newer\nProcessor:\nQuad-c...
# 8  Recommended:\nRequires a 64-bit processor and operating system\nOS:\nWindows 10\nProcessor:\nRyzen 3 1300X or Equiva...
# 9                                                           Recommended:\nRequires a 64-bit processor and operating system

# %% [markdown]
# ## 6. Parsing Hardware Requirements
#
# The raw Steam requirement text is converted into structured hardware fields.
# CPU and GPU requirements are retained as text, while RAM and storage are converted into numeric GB values where possible.

# %%
def extract_gb(text):

  if not text:
    return None

  match = re.search(
      r"(\d+(?:\.\d+)?)\s*(GB|MB)",
      text,
      flags=re.IGNORECASE
  )

  if not match:
    return None

  value = float(match.group(1))
  unit = match.group(2).upper()

  if unit == "MB":
      value = value / 1024

  return value

# %% [markdown]
# ## 7. Dynamic Hardware Parsing
#
# The retrieved minimum and recommended Steam requirements are dynamically converted into structured hardware fields for every game returned by the hybrid recommender.

# %%
def extract_first_available(text, field_names):

    for field in field_names:

        value = extract_requirement_field(
            text,
            field
        )

        if value is not None:
            return value

    return None

# %%
def parse_requirements(text):

    memory = extract_first_available(
        text,
        ["Memory", "RAM"]
    )

    storage = extract_first_available(
        text,
        ["Storage", "Hard Disk Space", "Hard Drive"]
    )

    return {
        "os": extract_first_available(
            text,
            ["OS", "OS *"]
        ),

        "cpu": extract_first_available(
            text,
            ["Processor", "CPU"]
        ),

        "ram_gb": extract_gb(memory),

        "gpu": extract_first_available(
            text,
            ["Graphics", "Video Card", "GPU"]
        ),

        "storage_gb": extract_gb(storage)
    }

# %% [markdown]
# ### Apply Parsing to All Recommended Games
#
# The parser is applied dynamically to every recommended game returned by the hybrid recommender, for both minimum and recommended hardware requirements.

# %%
parsed_min = hardware_test["minimum_requirements"].apply(
    parse_requirements
)

parsed_rec = hardware_test["recommended_requirements"].apply(
    parse_requirements
)

# %%
parsed_min.head()
# Out:
# 0    {'os': 'Windows XP SP3, Windows XP 64-bit SP2, Windows Vista SP2 (32- or 64-bit), or Windows 7 (32- or 64-bit). (Not...
# 1    {'os': '64-bit Windows 7 or later', 'cpu': 'Intel Core i3-4130 or equivalent with 4 hardware threads', 'ram_gb': 6.0...
# 2    {'os': 'Windows 7 (Service Pack 2) 32-Bit', 'cpu': 'Intel 2.4 GHz Core 2 Duo or AMD 2.8 GHz Athlon X2', 'ram_gb': 4....
# 3    {'os': 'WIndows 10, 64 Bit', 'cpu': '(AMD) Phenom II X4 965 or equivalent (Intel) Corei3-2120 or equivalent', 'ram_g...
# 4    {'os': 'Windows 7, 8.1, 10 64-bit', 'cpu': 'Intel i3 2120 @ 3.3GHz or Phenom II X4 965 @ 3.40GHz', 'ram_gb': 4.0, 'g...
# Name: minimum_requirements, dtype: object

# %% [markdown]
# ### Convert Parsed Requirements into Structured Columns
#
# The parsed minimum and recommended requirements are expanded into separate hardware columns for each recommended game.

# %%
min_df = pd.DataFrame(parsed_min.tolist()).add_prefix("min_")
rec_df = pd.DataFrame(parsed_rec.tolist()).add_prefix("rec_")

# %%
min_df.head()
# Out:
#                                                                                                                     min_os  \
# 0  Windows XP SP3, Windows XP 64-bit SP2, Windows Vista SP2 (32- or 64-bit), or Windows 7 (32- or 64-bit). (Not Support...
# 1                                                                                                64-bit Windows 7 or later
# 2                                                                                        Windows 7 (Service Pack 2) 32-Bit
# 3                                                                                                       WIndows 10, 64 Bit
# 4                                                                                                Windows 7, 8.1, 10 64-bit
#
#                                                                                                        min_cpu  \
# 0  Intel Core® 2 Duo 2.0 GHZ or AMD Athlon X2 64 2.4GHZ; 1.5 GB Windows® XP / 2 GB Windows Vista® - Windows 7®
# 1                                                     Intel Core i3-4130 or equivalent with 4 hardware threads
# 2                                                            Intel 2.4 GHz Core 2 Duo or AMD 2.8 GHz Athlon X2
# 3                                       (AMD) Phenom II X4 965 or equivalent (Intel) Corei3-2120 or equivalent
# 4                                                         Intel i3 2120 @ 3.3GHz or Phenom II X4 965 @ 3.40GHz
#
#    min_ram_gb  \
# 0         1.0
# 1         6.0
# 2         4.0
# 3         8.0
# 4         4.0
#
#                                                                                                                    min_gpu  \
# 0                               DirectX® 9.0c Compatible 3D-accelerated 256 MB video card with Shader Model 3.0* or higher
# 1              NVIDIA GeForce GTX 750 Ti 2GB, AMD Radeon HD 7850 2GB, or equivalent DX11 compatible GPU with 2GB of memory
# 2  AMD Radeon 3870 512 MB or higher performance; NVIDIA GeForce 8800 GT or higher performance; Intel HD 4000 Integrated...
# 3                                                 (AMD) Radeon HD 5870 or equivalent (Nvidia) GeForce GT 640 or equivalent
# 4                                                                                      NVidia GT 450 or ATI Radeon HD 5750
#
#    min_storage_gb
# 0             8.0
# 1            30.0
# 2            30.0
# 3            45.0
# 4             8.0

# %% [markdown]
# ### Combine Parsed Requirements with Hybrid Results
#
# The structured minimum and recommended hardware fields are combined with the original hybrid recommendation output.

# %%
hardware_parsed = pd.concat(
    [
        hardware_test.reset_index(drop=True),
        min_df.reset_index(drop=True),
        rec_df.reset_index(drop=True)
    ],
    axis=1
)

# %%
hardware_parsed[
    [
        "hybrid_rank",
        "recommended_game",
        "min_cpu",
        "min_ram_gb",
        "min_gpu",
        "min_storage_gb",
        "rec_cpu",
        "rec_ram_gb",
        "rec_gpu",
        "rec_storage_gb"
    ]
].head()
# Out:
#    hybrid_rank              recommended_game  \
# 0            1   Need For Speed: Hot Pursuit
# 1            2  Burnout™ Paradise Remastered
# 2            3               Need for Speed™
# 3            4        Need for Speed™ Rivals
# 4            5  Gas Guzzlers: Combat Carnage
#
#                                                                                                        min_cpu  \
# 0  Intel Core® 2 Duo 2.0 GHZ or AMD Athlon X2 64 2.4GHZ; 1.5 GB Windows® XP / 2 GB Windows Vista® - Windows 7®
# 1                                                         Intel i3 2120 @ 3.3GHz or Phenom II X4 965 @ 3.40GHz
# 2                                                     Intel Core i3-4130 or equivalent with 4 hardware threads
# 3                                                            Intel 2.4 GHz Core 2 Duo or AMD 2.8 GHz Athlon X2
# 4                                                                                            Dual-core 2.0 GHz
#
#    min_ram_gb  \
# 0     1.00000
# 1     4.00000
# 2     6.00000
# 3     4.00000
# 4     0.00293
#
#                                                                                                                    min_gpu  \
# 0                               DirectX® 9.0c Compatible 3D-accelerated 256 MB video card with Shader Model 3.0* or higher
# 1                                                                                      NVidia GT 450 or ATI Radeon HD 5750
# 2              NVIDIA GeForce GTX 750 Ti 2GB, AMD Radeon HD 7850 2GB, or equivalent DX11 compatible GPU with 2GB of memory
# 3  AMD Radeon 3870 512 MB or higher performance; NVIDIA GeForce 8800 GT or higher performance; Intel HD 4000 Integrated...
# 4               DirectX(R) 9 Compatible Graphics Card with SM 3.0. (GeForce(R) 8800 Ultra or 4850 AMD/ATi) with 512 MB RAM
#
#    min_storage_gb                                                   rec_cpu  \
# 0             8.0                                                      None
# 1             8.0                       Intel i5 3570K or AMD Ryzen 3 1300X
# 2            30.0  Intel Core i5-4690 or equivalent with 4 hardware threads
# 3            30.0                   Intel Quad-Core CPU or AMD Six Core CPU
# 4             7.0                     Quad-core Q6600 2.4 GHz or Equivalent
#
#    rec_ram_gb  \
# 0         NaN
# 1    8.000000
# 2    8.000000
# 3    8.000000
# 4    0.003906
#
#                                                                                                    rec_gpu  \
# 0                                                                                                     None
# 1                                                                   Nvidia GTX 750 Ti or AMD Radeon R7 265
# 2  NVIDIA GeForce GTX 970 4GB, AMD Radeon R9 290 4GB, or equivalent DX11 compatible GPU with 4GB of memory
# 3                AMD Radeon 7870 3GB or higher performance; NVIDIA GeForce GT660 3GB or higher performance
# 4                     DirectX(R) 9 Compatible Graphics Card (Radeon(R) 6850, GeForce(R) 560) with 1 GB RAM
#
#    rec_storage_gb
# 0             NaN
# 1             8.0
# 2            30.0
# 3            30.0
# 4             7.0

# %%
def get_hardware_topup(input_game, top_n=10):

    # Hybrid recommendations + raw Steam requirements
    results = get_hardware_requirements(
        input_game,
        top_n=top_n
    )

    # Parse minimum requirements
    parsed_min = results["minimum_requirements"].apply(
        parse_requirements
    )

    min_df = pd.DataFrame(
        parsed_min.tolist()
    ).add_prefix("min_")

    # Parse recommended requirements
    parsed_rec = results["recommended_requirements"].apply(
        parse_requirements
    )

    rec_df = pd.DataFrame(
        parsed_rec.tolist()
    ).add_prefix("rec_")

    # Combine everything
    final_results = pd.concat(
        [
            results.reset_index(drop=True),
            min_df,
            rec_df
        ],
        axis=1
    )

    return final_results

# %%
final_test = get_hardware_topup(
    "Dota 2",
    top_n=10
)

# %%
final_test[
    [
        "hybrid_rank",
        "recommended_game",
        "min_cpu",
        "min_ram_gb",
        "min_gpu",
        "min_storage_gb",
        "rec_cpu",
        "rec_ram_gb",
        "rec_gpu",
        "rec_storage_gb"
    ]
]
# Out:
#    hybrid_rank           recommended_game  \
# 0            1                Predecessor
# 1            2                   Dropzone
# 2            3  Clash: Mutants Vs Pirates
# 3            4                Iron League
# 4            5                       Zeal
# 5            6                    Strife®
# 6            7       Isekai Eternal Alpha
# 7            8            Rise of Legions
# 8            9             THE DAY Online
# 9           10     Tactical Genius Online
#
#                                                     min_cpu  min_ram_gb  \
# 0                           Intel® Core™ i5-4590 or similar         8.0
# 1                                         2.8 GHz Dual Core         4.0
# 2                            Intel i3 7100 or  AMD Rayzen 3         4.0
# 3                                            2GHz processor         1.0
# 4                                         Dual Core 2.5 GHz         8.0
# 5                         Dual-core Intel or AMD at 2.4 GHz         4.0
# 6  x86, x64 architecture with SSE2 instruction set support.         2.0
# 7                                                      None         4.0
# 8                    Dual core from Intel or AMD at 2.8 GHz         2.0
# 9                                     Dual Core CPU 2.0 GHz         4.0
#
#                                                                                                                    min_gpu  \
# 0                                                               NVIDIA GeForce GT 1030 2GB or AMD Radeon RX 550 equivalent
# 1                                                                                                        GTX 460 or better
# 2                                                         NVIDIA GeForce GTX 580 / Radeon HD 7870  (DirectX 11 Compatible)
# 3                                                                 Nvidia GT 530 / Radeon HD 7540D or equivalent video card
# 4                                                                                                       GTX 660/750 Ti 2GB
# 5                                 NVIDIA GeForce 8600 or higher, ATI/AMD Radeon HD 2600 or higher, Intel HD 2000 or higher
# 6                                                                                                DX10, DX11, DX12 capable.
# 7                                                                                               Any with at least 1GB VRAM
# 8                                                                                     NVIDIA 9800 GT 1GB / AMD HD 4870 1GB
# 9  Dedicated graphics card with 512MB memory. Can be played on integrated HD 3000 graphics (and better) with lowest qua...
#
#    min_storage_gb                           rec_cpu  rec_ram_gb  \
# 0            14.0  Intel® Core™ i5-11600 or similar        12.0
# 1             6.0                              None         NaN
# 2            10.0     Intel i5 7500 or AMD Rayzen 5         8.0
# 3             2.0                   3 GHz processor         2.0
# 4             5.0                 Quad Core 2.5 GHz        16.0
# 5             4.0                              None         NaN
# 6             2.0                              None         NaN
# 7             2.0                              None         4.0
# 8             3.0                              None         NaN
# 9             1.0             Dual Core CPU 2.0 GHz         4.0
#
#                                                                                                                    rec_gpu  \
# 0                                                               Nvidia GTX 1660 Ti 6GB or AMD Radeon RX 5600 XT equivalent
# 1                                                                                                                     None
# 2                                                                                                   NVIDIA GeForce GTX 950
# 3                                                                  Nvidia GT 730 / Radeon HD 5750 or equivalent video card
# 4                                                                                                             GTX 1060 3GB
# 5                                                                                                                     None
# 6                                                                                                                     None
# 7                                                                                               Any with at least 2GB VRAM
# 8                                                                                                                     None
# 9  Dedicated graphics card with 1GB memory. Tested on GeForce GT630 GDDR5-1GB 128bit (average quality). For high qualit...
#
#    rec_storage_gb
# 0            20.0
# 1             NaN
# 2            30.0
# 3             4.0
# 4             5.0
# 5             NaN
# 6             NaN
# 7             2.0
# 8             NaN
# 9             1.0

# %% [markdown]
# The hardware layer does not currently compare the retrieved requirements
# with a user-supplied hardware profile or perform hardware-based re-ranking.
# It acts as a post-recommendation enrichment layer.
